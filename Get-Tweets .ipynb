# %%
''' 
This main topic search function for Twitter using the python tweepy package
      Tries to get up to 100 results from the Twitter REST/Search API search function
        using the tweepy Cursor to repeat the twitter search api requests
      The query string may be a keyword or hashtag, or a set of them connected by or
        example:  query = "#CuseLAX OR CNYlacrosse"
        some queries require quotes on the command line
    Returns a list of json formatted tweets
'''

import tweepy
import json
import sys
from twitter_login_fn import oauth_login
from twitter_login_fn import appauth_login
from DB_fn import save_to_DB
from DB_fn import load_from_DB

sys.argv=['twitter_simple_search.py',100,'lax','syracuselax']

arg1 = '#disabilityTwitter'
arg2 = 100
arg3 = 'disabilityTwitter'
arg4 = 'disabilityTwittertweets'


'''
    Uses the tweepy Cursor to wrap a twitter api search for the query string
    Returns json formatted results
'''

def simple_search(api, query, max_results=20):
  # the first search initializes a cursor, stored in the metadata results,
  #   that allows next searches to return additional tweets
  search_results = [status for status in tweepy.Cursor(api.search, q=query).items(max_results)]
  
  # for each tweet, get the json representation
  tweets = [tweet._json for tweet in search_results]
  
  return tweets

# use a main so can get command line arguments
if __name__ == '__main__':
    # Make a list of command line arguments, omitting the [0] element
    # which is the script itself.
    args = sys.argv[1:]
 #   if not args or len(args) < 4:
 #       print('usage: python twitter_simple_search.py <query> <num tweets> <DB name> <collection name>')
 #       sys.exit(1)
query = arg1
num_tweets = int(arg2)
DBname = arg3
DBcollection = arg4

    # api = oauth_login()
    ''' if needed switch to using the appauth login to avoid rate limiting '''
api = appauth_login()
print ("Twitter Authorization: XSASNTJtq14b3jh0T0B3uFP6G, api")
    
    # access Twitter search
result_tweets = simple_search(api, query, max_results=num_tweets)
print ('Number of result tweets: ', len(result_tweets))

    # save the results in a database collection
    #   change names to lowercase because they are not case sensitive
    #   and remove special characters like hashtags and spaces (other special characters may also be forbidden)
DBname = DBname.lower()
DBname = DBname.replace('#', '')
DBname = DBname.replace(' ', '')
DBcollection = DBcollection.lower()
DBcollection = DBcollection.replace('#', '')
DBcollection = DBcollection.replace(' ', '')
    
    # use the save and load functions in this program
save_to_DB(DBname, DBcollection, result_tweets)
load_from_DB(DBname, DBcollection)
    # Done!
# Out:
#   File "<ipython-input-2-69d2a3138bcf>", line 56
#     ''' if needed switch to using the appauth login to avoid rate limiting '''
#     ^
# IndentationError: unexpected indent

# %%
import pymongo
client = pymongo.MongoClient('localhost', 27017)
client.list_database_names()
# Out:
# ['DD', 'admin', 'config', 'local', 'peopledb', 'usgs']

# %%
db = client.disney
db.list_collection_names()
# Out:
# []

# %%
coll = db.disneytweets
docs = coll.find()

def print_tweet_data(tweets):
    for tweet in tweets:
        if tweet['retweet_count']<10:
           print('\nDate: ',tweet['created_at'])
           print('From: ',tweet['user']['name'])
           print('Message: ',tweet['text'])
           print('Retweet Count:',tweet['retweet_count'])
      
print_tweet_data(docs)
# Out:
# Date:  Tue May 19 16:05:43 +0000 2020
# From:  Dani Calabresa
# Message:  ºoº Mickey, tchô me isolá aí no mundo mágico vai..✨🏰💕 #disney #magickingdom https://t.co/KfsmE8gqLz https://t.co/2dDt5MzXRn
# Retweet Count: 0
#
# Date:  Tue May 19 16:05:40 +0000 2020
# From:  Martina
# Retweet Count: 2
#
# Date:  Tue May 19 15:49:38 +0000 2020
# From:  Yoav Leidner
# Message:  RT @THR: Rebecca Campbell is replacing Kevin Mayer, the architect behind #DisneyPlus who has left #Disney to become CEO of #TikTok. So what…
# Retweet Count: 4
#
# Date:  Tue May 19 15:49:18 +0000 2020
# From:  The Hollywood Reporter
# Message:  Rebecca Campbell is replacing Kevin Mayer, the architect behind #DisneyPlus who has left #Disney to become CEO of… https://t.co/41bQLTTwwy
# Retweet Count: 4
#
# Date:  Tue May 19 15:49:12 +0000 2020
# From:  NutellaNinja
# Message:  #disney #disneydeutschland #disneyde  #disneylove  #mogli #love #tofublunk #disneylivezeichnen #disneylivelettering… https://t.co/juKNArIOFb
# Retweet Count: 0
#
# Date:  Tue May 19 15:49:05 +0000 2020
# From:  Magic Expeditions
# Message:  In 2021, #AdventuresbyDisney is adding NEW adventures!  Embark on incredible expeditions to #NewZealand, #Portugal,… https://t.co/askYNp7Y4f
# Retweet Count: 0

# %%
import tweepy
import json
import sys
from twitter_login_fn import oauth_login
from twitter_login_fn import appauth_login
from DB_fn import save_to_DB
from DB_fn import load_from_DB

sys.argv=['twitter_simple_search.py',100,'lax','syracuselax']

arg1 = '#disabilityTwitter'
arg2 = 100
arg3 = 'disabilityTwitter'
arg4 = 'disabilityTwittertweets'

def simple_search(api, query, max_results=20):
  search_results = [status for status in tweepy.Cursor(api.search, q=query).items(max_results)]

  tweets = [tweet._json for tweet in search_results]
  
  return tweets

if __name__ == '__main__':
    args = sys.argv[1:]
 #   if not args or len(args) < 4:
 #       print('usage: python twitter_simple_search.py <query> <num tweets> <DB name> <collection name>')
 #       sys.exit(1)
query = arg1
num_tweets = int(arg2)
DBname = arg3
DBcollection = arg4

api = oauth_login()
print ("Twitter Authorization: AAAAAAAAAAAAAAAAAAAAAJM6GAEAAAAADoi6DMkhU4OK%2FMtlSKjPt7W8Njg%3DFZ59IKlrB6WBntvbnzd9MJ1IoX4JhK3J7H99QzI7FdzTYRvCZ9
, api")
api = appauth_login()
print ("Twitter Authorization: G4XthTYn0E4Zk3ZnfqRIHtWpZIrAxwVFAVWZlYXFwTzRqfEMsT, api")
    
# access Twitter search
result_tweets = simple_search(api, query, max_results=num_tweets)
print ('Number of result tweets: ', len(result_tweets))

# save the results in a database collection
# and remove special characters like hashtags and spaces (other special characters may also be forbidden)
DBname = DBname.lower()
DBname = DBname.replace('#', '')
DBname = DBname.replace(' ', '')
DBcollection = DBcollection.lower()
DBcollection = DBcollection.replace('#', '')
DBcollection = DBcollection.replace(' ', '')
    
# use the save and load functions in this program
save_to_DB(DBname, DBcollection, result_tweets)
load_from_DB(DBname, DBcollection)
# Out:
#   File "<ipython-input-17-a8af6046f003>", line 34
#     print ("Twitter Authorization: AAAAAAAAAAAAAAAAAAAAAJM6GAEAAAAADoi6DMkhU4OK%2FMtlSKjPt7W8Njg%3DFZ59IKlrB6WBntvbnzd9MJ1IoX4JhK3J7H99QzI7FdzTYRvCZ9
#                                                                                                                                                      ^
# SyntaxError: EOL while scanning string literal
